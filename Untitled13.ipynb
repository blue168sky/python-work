# %%
# %matplotlib inline
import pymc
import mymodel

# %%
S = pymc.MCMC(mymodel,db = 'pickle')
S.sample(iter = 10000, burn = 5000,thin =2)
pymc.Matplot.plot(S)
# Out:
#  [-----------------100%-----------------] 10000 of 10000 complete in 0.9 secPlotting betaa
# Plotting alpha
# Plotting d_0
# Plotting d_1
# Plotting d_2
# Plotting d_3
# Plotting theta_0
# Plotting theta_1
# Plotting theta_2
# Plotting theta_3
